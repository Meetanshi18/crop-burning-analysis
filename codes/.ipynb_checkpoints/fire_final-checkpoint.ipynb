# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

import tensorflow as tf
from tensorflow.python.data import Dataset

tf.logging.set_verbosity(tf.logging.ERROR)

# %%
data=pd.read_csv('fire_archive_M6_67636.csv')
print(data.shape)
for i in range(len(data)): 
    data.loc[i,'Day'] = int(data.loc[i,'acq_date'].split('-')[2])
    data.loc[i,'Month'] = int(data.loc[i,'acq_date'].split('-')[1])
    data.loc[i,'Year'] = int(data.loc[i,'acq_date'].split('-')[0])
#print(data['Day'][0])
#print(data['Month'][0])
#print(data['Year'][0])
#print(data.head())
print(data.shape)
data.head()
data.tail()
# Out:
# (33241, 15)
# (33241, 18)
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 33236   30.2090    75.5844       305.1   1.1    1.0  2019-03-24       554
# 33237   29.9832    75.7878       307.8   1.0    1.0  2019-03-26       542
# 33238   31.4244    75.6443       315.9   1.4    1.2  2019-03-28       529
# 33239   31.4744    75.6168       314.5   1.8    1.3  2019-03-29       612
# 33240   30.2464    74.2578       312.5   1.1    1.0  2019-03-31       600
#
#       satellite instrument  confidence  version  bright_t31   frp daynight  \
# 33236     Terra      MODIS          51      6.3       292.4   4.4        D
# 33237     Terra      MODIS          51      6.3       297.5   4.7        D
# 33238     Terra      MODIS          68      6.3       300.3  11.4        D
# 33239     Terra      MODIS          71      6.3       299.6  13.5        D
# 33240     Terra      MODIS          53      6.3       300.9   6.9        D
#
#        type   Day  Month    Year
# 33236     0  24.0    3.0  2019.0
# 33237     0  26.0    3.0  2019.0
# 33238     0  28.0    3.0  2019.0
# 33239     0  29.0    3.0  2019.0
# 33240     0  31.0    3.0  2019.0

# %%
date=data['acq_date']

# %%
#data.describe()
# Out:
#            latitude     longitude    brightness          scan         track  \
# count  33241.000000  33241.000000  33241.000000  33241.000000  33241.000000
# mean      30.402413     75.299371    320.834151      1.358178      1.131753
# std        0.524559      0.679308      9.048738      0.555128      0.182780
# min       28.700100     74.000200    300.100000      1.000000      1.000000
# 25%       30.045400     74.727100    314.400000      1.000000      1.000000
# 50%       30.414500     75.252900    318.400000      1.100000      1.100000
# 75%       30.780000     75.819400    326.000000      1.500000      1.200000
# max       31.499900     76.799900    400.000000      4.800000      2.000000
#
#            acq_time    confidence       version    bright_t31           frp  \
# count  33241.000000  33241.000000  33241.000000  33241.000000  33241.000000
# mean     782.800818     62.489727      6.200316    301.783716     16.650453
# std      118.720236     16.061561      0.005611      5.413613     16.026196
# min      459.000000      0.000000      6.200000    275.000000      2.500000
# 25%      759.000000     53.000000      6.200000    299.000000      8.200000
# 50%      812.000000     65.000000      6.200000    300.900000     12.500000
# 75%      824.000000     74.000000      6.200000    303.100000     19.800000
# max     2124.000000    100.000000      6.300000    328.600000   1104.700000
#
#                type           Day         Month          Year
# count  33241.000000  33241.000000  33241.000000  33241.000000
# mean       0.000722     15.857886      9.605577   2017.556722
# std        0.037994      9.449423      2.250042      0.503098
# min        0.000000      1.000000      1.000000   2017.000000
# 25%        0.000000      7.000000     10.000000   2017.000000
# 50%        0.000000     16.000000     10.000000   2018.000000
# 75%        0.000000     24.000000     11.000000   2018.000000
# max        2.000000     31.000000     12.000000   2019.000000

# %%
#data.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   29.7427    76.6679       328.7   2.9    1.6  2017-05-01       618
# 1   30.4988    74.0669       333.4   1.9    1.3  2017-05-01       618
# 2   30.2280    75.1271       330.2   2.3    1.5  2017-05-01       618
# 3   30.5747    75.5177       328.7   2.3    1.5  2017-05-01       618
# 4   30.4250    75.3941       334.0   2.3    1.5  2017-05-01       618
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type  \
# 0     Terra      MODIS          68      6.2       311.5  48.2        D     0
# 1     Terra      MODIS          77      6.2       312.7  33.6        D     0
# 2     Terra      MODIS          73      6.2       315.3  28.3        D     0
# 3     Terra      MODIS          73      6.2       312.8  27.4        D     0
# 4     Terra      MODIS          80      6.2       313.5  47.6        D     0
#
#    Day  Month    Year
# 0  1.0    5.0  2017.0
# 1  1.0    5.0  2017.0
# 2  1.0    5.0  2017.0
# 3  1.0    5.0  2017.0
# 4  1.0    5.0  2017.0

# %%
cormat=data.corr()
fig=plt.figure(figsize =(12,9))
sns.heatmap(cormat,vmax=.8,square=True)
plt.show()
cormat
# Out:
#             latitude  longitude  brightness      scan     track  acq_time  \
# latitude    1.000000  -0.257209   -0.025407 -0.021596 -0.026854  0.053881
# longitude  -0.257209   1.000000   -0.019692  0.000600  0.002489 -0.046336
# brightness -0.025407  -0.019692    1.000000 -0.126525 -0.128035 -0.198767
# scan       -0.021596   0.000600   -0.126525  1.000000  0.977876 -0.032919
# track      -0.026854   0.002489   -0.128035  0.977876  1.000000 -0.040071
# acq_time    0.053881  -0.046336   -0.198767 -0.032919 -0.040071  1.000000
# confidence  0.049770   0.033947    0.621403 -0.067649 -0.070337 -0.056706
# version     0.012660   0.016106   -0.079551 -0.011791 -0.014472 -0.039722
# bright_t31 -0.029996   0.070922    0.675406 -0.095761 -0.090874 -0.309663
# frp        -0.012271  -0.035254    0.543106  0.473770  0.456859 -0.029142
# type        0.009663  -0.015150   -0.025851  0.002002  0.001031 -0.016042
# Day         0.042461  -0.006322   -0.121279 -0.014191 -0.010601  0.060368
# Month      -0.067475  -0.111869   -0.495018 -0.037302 -0.038528  0.235731
# Year       -0.011671  -0.037035    0.053454 -0.004206 -0.005732 -0.058077
#
#             confidence   version  bright_t31       frp      type       Day  \
# latitude      0.049770  0.012660   -0.029996 -0.012271  0.009663  0.042461
# longitude     0.033947  0.016106    0.070922 -0.035254 -0.015150 -0.006322
# brightness    0.621403 -0.079551    0.675406  0.543106 -0.025851 -0.121279
# scan         -0.067649 -0.011791   -0.095761  0.473770  0.002002 -0.014191
# track        -0.070337 -0.014472   -0.090874  0.456859  0.001031 -0.010601
# acq_time     -0.056706 -0.039722   -0.309663 -0.029142 -0.016042  0.060368
# confidence    1.000000 -0.017772    0.300212  0.418285 -0.008862 -0.012378
# version      -0.017772  1.000000   -0.102645 -0.020202  0.337588 -0.009196
# bright_t31    0.300212 -0.102645    1.000000  0.143294 -0.035983 -0.042566
# frp           0.418285 -0.020202    0.143294  1.000000 -0.000346 -0.042292
# type         -0.008862  0.337588   -0.035983 -0.000346  1.000000  0.008330
# Day          -0.012378 -0.009196   -0.042566 -0.042292  0.008330  1.000000
# Month        -0.196527 -0.191471   -0.648343 -0.160371 -0.067755  0.055010
# Year          0.052924  0.161491   -0.018840  0.040426  0.054517 -0.202604
#
#                Month      Year
# latitude   -0.067475 -0.011671
# longitude  -0.111869 -0.037035
# brightness -0.495018  0.053454
# scan       -0.037302 -0.004206
# track      -0.038528 -0.005732
# acq_time    0.235731 -0.058077
# confidence -0.196527  0.052924
# version    -0.191471  0.161491
# bright_t31 -0.648343 -0.018840
# frp        -0.160371  0.040426
# type       -0.067755  0.054517
# Day         0.055010 -0.202604
# Month       1.000000 -0.059473
# Year       -0.059473  1.000000

# %%
Adata=data[['latitude','longitude','brightness'  ,'scan' , 'track','acq_time','confidence',  'version' , 'bright_t31'  , 'frp' ,'type','Day' , 'Month','Year']]
Adata.head()
# Out:
#    latitude  longitude  brightness  scan  track  acq_time  confidence  \
# 0   29.7427    76.6679       328.7   2.9    1.6       618          68
# 1   30.4988    74.0669       333.4   1.9    1.3       618          77
# 2   30.2280    75.1271       330.2   2.3    1.5       618          73
# 3   30.5747    75.5177       328.7   2.3    1.5       618          73
# 4   30.4250    75.3941       334.0   2.3    1.5       618          80
#
#    version  bright_t31   frp  type  Day  Month    Year
# 0      6.2       311.5  48.2     0  1.0    5.0  2017.0
# 1      6.2       312.7  33.6     0  1.0    5.0  2017.0
# 2      6.2       315.3  28.3     0  1.0    5.0  2017.0
# 3      6.2       312.8  27.4     0  1.0    5.0  2017.0
# 4      6.2       313.5  47.6     0  1.0    5.0  2017.0

# %%
br=data['brightness']
br_31=data['bright_t31']
mon=data['Month']
con=data['confidence']
pwr=data['frp']
print(br.shape)
print(br_31.shape)
print(mon.shape)
print(con.shape)
# Out:
# (33241,)
# (33241,)
# (33241,)
# (33241,)

# %%
def scatterplot(y2,y1,x_label=" ",y_label=" ",title=" ",color="b",yscale_log=False):
    _, ax=plt.subplots()
    ax.scatter(y2,y1,s=10, color = color, alpha=0.75)
    
    if yscale_log==True:
        ax.set_yscale('log')
        
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

scatterplot(mon,br,'month','brightness')
scatterplot(mon,br_31,'month')
scatterplot(br,con,'brightness','confidence')
scatterplot(mon,con,'month','confidence')
scatterplot(mon,pwr,'month','fpr')
scatterplot(con,pwr,'con','fpr')

# %%
plt.figure(figsize=(20, 10))

ax = plt.subplot(1,2,2)
ax.set_title("Data")

ax.set_autoscaley_on(False)
ax.set_ylim([28, 32])
ax.set_autoscalex_on(False)
ax.set_xlim([73, 78])
plt.scatter(data["longitude"],
            data["latitude"],
            cmap="coolwarm",
            c=data["confidence"] / data["confidence"].max())
_ = plt.plot()

# %%
columns = np.full((cormat.shape[0],), True, dtype=bool)
for i in range(cormat.shape[0]):
    for j in range(i+1, cormat.shape[0]):
        if cormat.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False
                
selected_columns =Adata.columns[columns]
data = data[selected_columns]
data['acq_date']=date
print(columns)
print(selected_columns)
data.head()
# Out:
# [ True  True  True  True False  True  True  True  True  True  True  True
#   True  True]
# Index(['latitude', 'longitude', 'brightness', 'scan', 'acq_time', 'confidence',
#        'version', 'bright_t31', 'frp', 'type', 'Day', 'Month', 'Year'],
#       dtype='object')
#    latitude  longitude  brightness  scan  acq_time  confidence  version  \
# 0   29.7427    76.6679       328.7   2.9       618          68      6.2
# 1   30.4988    74.0669       333.4   1.9       618          77      6.2
# 2   30.2280    75.1271       330.2   2.3       618          73      6.2
# 3   30.5747    75.5177       328.7   2.3       618          73      6.2
# 4   30.4250    75.3941       334.0   2.3       618          80      6.2
#
#    bright_t31   frp  type  Day  Month    Year    acq_date
# 0       311.5  48.2     0  1.0    5.0  2017.0  2017-05-01
# 1       312.7  33.6     0  1.0    5.0  2017.0  2017-05-01
# 2       315.3  28.3     0  1.0    5.0  2017.0  2017-05-01
# 3       312.8  27.4     0  1.0    5.0  2017.0  2017-05-01
# 4       313.5  47.6     0  1.0    5.0  2017.0  2017-05-01

# %%
l=list(selected_columns.values)
l.remove('confidence')
features=data[l]
print(features.head())
target = pd.DataFrame()
target=data[['confidence']]
print(target.head())
target.describe()
# Out:
#    latitude  longitude  brightness  scan  acq_time  version  bright_t31   frp  \
# 0   29.7427    76.6679       328.7   2.9       618      6.2       311.5  48.2
# 1   30.4988    74.0669       333.4   1.9       618      6.2       312.7  33.6
# 2   30.2280    75.1271       330.2   2.3       618      6.2       315.3  28.3
# 3   30.5747    75.5177       328.7   2.3       618      6.2       312.8  27.4
# 4   30.4250    75.3941       334.0   2.3       618      6.2       313.5  47.6
#
#    type  Day  Month    Year
# 0     0  1.0    5.0  2017.0
# 1     0  1.0    5.0  2017.0
# 2     0  1.0    5.0  2017.0
# 3     0  1.0    5.0  2017.0
# 4     0  1.0    5.0  2017.0
#    confidence
# 0          68
# 1          77
# 2          73
# 3          73
# 4          80
#          confidence
# count  33241.000000
# mean      62.489727
# std       16.061561
# min        0.000000
# 25%       53.000000
# 50%       65.000000
# 75%       74.000000
# max      100.000000

# %%
for i in target.index:
    if target['confidence'][i]<=40:
        target.at[i, 'confidence'] = 0
    elif target['confidence'][i]<=65:
        target.at[i, 'confidence'] = 1
    else:
        target.at[i, 'confidence'] = 2

# %%
target['confidence']
target.describe()
# Out:
#          confidence
# count  33241.000000
# mean       1.372883
# std        0.668464
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000

# %%
fig = plt.figure(figsize = (20, 25))
j = 0
for i in features.columns:
    plt.subplot(6, 4, j+1)
    j += 1
    sns.distplot(features[i][target['confidence']==0], color='y', label = 'low-confidence fire')
    sns.distplot(features[i][target['confidence']==1], color='g', label = 'nominal-confidence fire')
    sns.distplot(features[i][target['confidence']==2], color='r', label = 'high-confidence fire')
    plt.legend(loc='best')
fig.suptitle('Crop Burning Analysis')
fig.tight_layout()
fig.subplots_adjust(top=0.95)
plt.show()

# %%
data.to_pickle("fire_data.pkl")

# %%
abc = pd.read_pickle("fire_data.pkl")

# %%
abc.head()
# Out:
#    latitude  longitude  brightness  scan  acq_time  confidence  version  \
# 0   29.7427    76.6679       328.7   2.9       618          68      6.2
# 1   30.4988    74.0669       333.4   1.9       618          77      6.2
# 2   30.2280    75.1271       330.2   2.3       618          73      6.2
# 3   30.5747    75.5177       328.7   2.3       618          73      6.2
# 4   30.4250    75.3941       334.0   2.3       618          80      6.2
#
#    bright_t31   frp  type  Day  Month    Year    acq_date
# 0       311.5  48.2     0  1.0    5.0  2017.0  2017-05-01
# 1       312.7  33.6     0  1.0    5.0  2017.0  2017-05-01
# 2       315.3  28.3     0  1.0    5.0  2017.0  2017-05-01
# 3       312.8  27.4     0  1.0    5.0  2017.0  2017-05-01
# 4       313.5  47.6     0  1.0    5.0  2017.0  2017-05-01
