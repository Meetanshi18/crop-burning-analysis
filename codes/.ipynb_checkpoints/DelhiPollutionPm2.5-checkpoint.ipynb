# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

import tensorflow as tf
from tensorflow.python.data import Dataset

tf.logging.set_verbosity(tf.logging.ERROR)

# %%
dt=pd.read_csv('delhipm2.5.csv')
print(dt.head())
dt.describe()
# Out:
#    Year  F_Month  F_Day  UTC Hour  PM2.5  Month  Day    acq_date
# 0  2016        3      3         8  123.8      3    3  2016-03-03
# 1  2016        3      3         9  141.6      3    3  2016-03-03
# 2  2016        3      3        10  133.9      3    3  2016-03-03
# 3  2016        3      3        11  134.5      3    3  2016-03-03
# 4  2016        3      3        12  142.7      3    3  2016-03-03
#                Year       F_Month         F_Day      UTC Hour         PM2.5  \
# count  27982.000000  27982.000000  27982.000000  27982.000000  27982.000000
# mean    2017.402259      6.525588     15.636731     11.487921    105.600743
# std        1.043361      3.250329      8.729290      6.925648     84.443408
# min     2016.000000      1.000000      1.000000      0.000000      4.600000
# 25%     2017.000000      4.000000      8.000000      5.000000     49.400000
# 50%     2017.000000      7.000000     16.000000     11.000000     78.700000
# 75%     2018.000000      9.000000     23.000000     18.000000    135.900000
# max     2019.000000     12.000000     31.000000     23.000000    781.300000
#
#               Month           Day
# count  27982.000000  27982.000000
# mean       6.525588     15.636731
# std        3.250329      8.729290
# min        1.000000      1.000000
# 25%        4.000000      8.000000
# 50%        7.000000     16.000000
# 75%        9.000000     23.000000
# max       12.000000     31.000000

# %%
data=pd.DataFrame()
data=dt[['Year','Month','Day','UTC Hour','acq_date','PM2.5']]
data.head()
# Out:
#    Year  Month  Day  UTC Hour    acq_date  PM2.5
# 0  2016      3    3         8  2016-03-03  123.8
# 1  2016      3    3         9  2016-03-03  141.6
# 2  2016      3    3        10  2016-03-03  133.9
# 3  2016      3    3        11  2016-03-03  134.5
# 4  2016      3    3        12  2016-03-03  142.7

# %%
type(data['acq_date'][0])
# Out:
# str

# %%
def scatterplot(y2,y1,x_label=" ",y_label=" ",title=" ",color="b",yscale_log=False):
    _, ax=plt.subplots()
    ax.scatter(y2,y1,s=10, color = color, alpha=0.75)
    
    if yscale_log==True:
        ax.set_yscale('log')
        
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

Mon=data['Month']
Pm=data['PM2.5']
Hr=data['UTC Hour']    
scatterplot(Mon,Pm,'month','PM_2.5')
scatterplot(Hr,Pm,'hour','PM_2.5')

# %%
b=data.groupby('Month').count()
b
# Out:
#        Year   Day  UTC Hour  acq_date  PM2.5
# Month
# 1      1940  1940      1940      1940   1940
# 2      1738  1738      1738      1738   1738
# 3      2618  2618      2618      2618   2618
# 4      2112  2112      2112      2112   2112
# 5      2880  2880      2880      2880   2880
# 6      2551  2551      2551      2551   2551
# 7      2741  2741      2741      2741   2741
# 8      2672  2672      2672      2672   2672
# 9      2635  2635      2635      2635   2635
# 10     2125  2125      2125      2125   2125
# 11     1993  1993      1993      1993   1993
# 12     1977  1977      1977      1977   1977

# %%
Aggregation={'PM2.5':'mean'}
a=pd.DataFrame()
a=data.groupby(['Year','Month','Day']).agg(Aggregation).reset_index()
a["acq_date"] = data["acq_date"]
a.head()
#type(a['acq_date'][0])
# Out:
# str

# %%
fire_data = pd.read_pickle("fire_data.pkl")

# %%
fire_data.head()
# Out:
#    latitude  longitude  brightness  scan  acq_time  confidence  version  \
# 0   29.7427    76.6679       328.7   2.9       618          68      6.2
# 1   30.4988    74.0669       333.4   1.9       618          77      6.2
# 2   30.2280    75.1271       330.2   2.3       618          73      6.2
# 3   30.5747    75.5177       328.7   2.3       618          73      6.2
# 4   30.4250    75.3941       334.0   2.3       618          80      6.2
#
#    bright_t31   frp  type  Day  Month    Year    acq_date
# 0       311.5  48.2     0  1.0    5.0  2017.0  2017-05-01
# 1       312.7  33.6     0  1.0    5.0  2017.0  2017-05-01
# 2       315.3  28.3     0  1.0    5.0  2017.0  2017-05-01
# 3       312.8  27.4     0  1.0    5.0  2017.0  2017-05-01
# 4       313.5  47.6     0  1.0    5.0  2017.0  2017-05-01

# %%
type(fire_data['acq_date'][0])
# Out:
# str

# %%
combined = pd.merge(data, fire_data, on="acq_date", how="inner")

# %%
combined
# Out:
#         Year_x  Month_x  Day_x  UTC Hour    acq_date  PM2.5  latitude  \
# 0         2017        5      1         0  2017-05-01   57.1   29.7427
# 1         2017        5      1         0  2017-05-01   57.1   30.4988
# 2         2017        5      1         0  2017-05-01   57.1   30.2280
# 3         2017        5      1         0  2017-05-01   57.1   30.5747
# 4         2017        5      1         0  2017-05-01   57.1   30.4250
# ...        ...      ...    ...       ...         ...    ...       ...
# 746777    2019        3     31        19  2019-03-31   50.3   30.2464
# 746778    2019        3     31        20  2019-03-31   50.2   30.2464
# 746779    2019        3     31        21  2019-03-31   50.2   30.2464
# 746780    2019        3     31        22  2019-03-31   39.9   30.2464
# 746781    2019        3     31        23  2019-03-31   38.8   30.2464
#
#         longitude  brightness  scan  acq_time  confidence  version  \
# 0         76.6679       328.7   2.9       618          68      6.2
# 1         74.0669       333.4   1.9       618          77      6.2
# 2         75.1271       330.2   2.3       618          73      6.2
# 3         75.5177       328.7   2.3       618          73      6.2
# 4         75.3941       334.0   2.3       618          80      6.2
# ...           ...         ...   ...       ...         ...      ...
# 746777    74.2578       312.5   1.1       600          53      6.3
# 746778    74.2578       312.5   1.1       600          53      6.3
# 746779    74.2578       312.5   1.1       600          53      6.3
# 746780    74.2578       312.5   1.1       600          53      6.3
# 746781    74.2578       312.5   1.1       600          53      6.3
#
#         bright_t31   frp  type  Day_y  Month_y  Year_y
# 0            311.5  48.2     0    1.0      5.0  2017.0
# 1            312.7  33.6     0    1.0      5.0  2017.0
# 2            315.3  28.3     0    1.0      5.0  2017.0
# 3            312.8  27.4     0    1.0      5.0  2017.0
# 4            313.5  47.6     0    1.0      5.0  2017.0
# ...            ...   ...   ...    ...      ...     ...
# 746777       300.9   6.9     0   31.0      3.0  2019.0
# 746778       300.9   6.9     0   31.0      3.0  2019.0
# 746779       300.9   6.9     0   31.0      3.0  2019.0
# 746780       300.9   6.9     0   31.0      3.0  2019.0
# 746781       300.9   6.9     0   31.0      3.0  2019.0
#
# [746782 rows x 19 columns]

# %%
Aggregation={'PM2.5':'mean'}
combined_data=pd.DataFrame()
combined_data=combined.groupby(['Year_x','Month_x','Day_x']).agg(Aggregation).reset_index()
# a["acq_date"] = data["acq_date"]
combined_data.head()
#type(a['acq_date'][0])
# Out:
#    Year_x  Month_x  Day_x       PM2.5
# 0    2017        5      1   92.170833
# 1    2017        5      2  133.978261
# 2    2017        5      3  119.283333
# 3    2017        5      4  136.308696
# 4    2017        5      5  159.175000

# %%
columns = list(['latitude', 'longitude', 'brightness', 'scan', 'confidence', 'bright_t31', 'frp'])

combined_data[columns] = combined[columns]

# %%
combined_data.head()
# Out:
#    Year_x  Month_x  Day_x       PM2.5  latitude  longitude  brightness  scan  \
# 0    2017        5      1   92.170833   29.7427    76.6679       328.7   2.9
# 1    2017        5      2  133.978261   30.4988    74.0669       333.4   1.9
# 2    2017        5      3  119.283333   30.2280    75.1271       330.2   2.3
# 3    2017        5      4  136.308696   30.5747    75.5177       328.7   2.3
# 4    2017        5      5  159.175000   30.4250    75.3941       334.0   2.3
#
#    confidence  bright_t31   frp
# 0          68       311.5  48.2
# 1          77       312.7  33.6
# 2          73       315.3  28.3
# 3          73       312.8  27.4
# 4          80       313.5  47.6
