# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

import tensorflow as tf
from tensorflow.python.data import Dataset

tf.logging.set_verbosity(tf.logging.ERROR)

# %%
dt=pd.read_csv('../Datasets/delhipm2.5.csv')
print(dt.head())
dt.describe()
# Out:
#    Year  F_Month  F_Day  UTC Hour  PM2.5  Month  Day    acq_date
# 0  2016        3      3         8  123.8      3    3  2016-03-03
# 1  2016        3      3         9  141.6      3    3  2016-03-03
# 2  2016        3      3        10  133.9      3    3  2016-03-03
# 3  2016        3      3        11  134.5      3    3  2016-03-03
# 4  2016        3      3        12  142.7      3    3  2016-03-03
#                Year       F_Month         F_Day      UTC Hour         PM2.5  \
# count  27982.000000  27982.000000  27982.000000  27982.000000  27982.000000
# mean    2017.402259      6.525588     15.636731     11.487921    105.600743
# std        1.043361      3.250329      8.729290      6.925648     84.443408
# min     2016.000000      1.000000      1.000000      0.000000      4.600000
# 25%     2017.000000      4.000000      8.000000      5.000000     49.400000
# 50%     2017.000000      7.000000     16.000000     11.000000     78.700000
# 75%     2018.000000      9.000000     23.000000     18.000000    135.900000
# max     2019.000000     12.000000     31.000000     23.000000    781.300000
#
#               Month           Day
# count  27982.000000  27982.000000
# mean       6.525588     15.636731
# std        3.250329      8.729290
# min        1.000000      1.000000
# 25%        4.000000      8.000000
# 50%        7.000000     16.000000
# 75%        9.000000     23.000000
# max       12.000000     31.000000

# %%
data=pd.DataFrame()
data=dt[['Year','Month','Day','UTC Hour','acq_date','PM2.5']]
data.head()
# Out:
#    Year  Month  Day  UTC Hour    acq_date  PM2.5
# 0  2016      3    3         8  2016-03-03  123.8
# 1  2016      3    3         9  2016-03-03  141.6
# 2  2016      3    3        10  2016-03-03  133.9
# 3  2016      3    3        11  2016-03-03  134.5
# 4  2016      3    3        12  2016-03-03  142.7

# %%
type(data['acq_date'][0])
# Out:
# str

# %%
def scatterplot(y2,y1,x_label=" ",y_label=" ",title=" ",color="b",yscale_log=False):
    _, ax=plt.subplots()
    ax.scatter(y2,y1,s=10, color = color, alpha=0.75)
    
    if yscale_log==True:
        ax.set_yscale('log')
        
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

Mon=data['Month']
Pm=data['PM2.5']
Hr=data['UTC Hour']    
scatterplot(Mon,Pm,'month','PM_2.5')
scatterplot(Hr,Pm,'hour','PM_2.5')

# %%
b=data.groupby('Month').count()
b
# Out:
#        Year   Day  UTC Hour  acq_date  PM2.5
# Month
# 1      1940  1940      1940      1940   1940
# 2      1738  1738      1738      1738   1738
# 3      2618  2618      2618      2618   2618
# 4      2112  2112      2112      2112   2112
# 5      2880  2880      2880      2880   2880
# 6      2551  2551      2551      2551   2551
# 7      2741  2741      2741      2741   2741
# 8      2672  2672      2672      2672   2672
# 9      2635  2635      2635      2635   2635
# 10     2125  2125      2125      2125   2125
# 11     1993  1993      1993      1993   1993
# 12     1977  1977      1977      1977   1977

# %%
Aggregation={'PM2.5':'mean'}
a=pd.DataFrame()
a=data.groupby(['Year','Month','Day']).agg(Aggregation).reset_index()
a["acq_date"] = data["acq_date"]
a.head()
#type(a['acq_date'][0])
# Out:
#    Year  Month  Day       PM2.5    acq_date
# 0  2016      3    3  135.720000  2016-03-03
# 1  2016      3    4   62.595833  2016-03-03
# 2  2016      3    5   54.475000  2016-03-03
# 3  2016      3    6   84.350000  2016-03-03
# 4  2016      3    7   92.941667  2016-03-03

# %%
fire_data = pd.read_pickle("fire_data.pkl")

# %%
fire_data.head()
# Out:
#    latitude  longitude  brightness  scan  acq_time  confidence  version  \
# 0   29.7427    76.6679       328.7   2.9       618          68      6.2
# 1   30.4988    74.0669       333.4   1.9       618          77      6.2
# 2   30.2280    75.1271       330.2   2.3       618          73      6.2
# 3   30.5747    75.5177       328.7   2.3       618          73      6.2
# 4   30.4250    75.3941       334.0   2.3       618          80      6.2
#
#    bright_t31   frp  type  Day  Month    Year    acq_date
# 0       311.5  48.2     0  1.0    5.0  2017.0  2017-05-01
# 1       312.7  33.6     0  1.0    5.0  2017.0  2017-05-01
# 2       315.3  28.3     0  1.0    5.0  2017.0  2017-05-01
# 3       312.8  27.4     0  1.0    5.0  2017.0  2017-05-01
# 4       313.5  47.6     0  1.0    5.0  2017.0  2017-05-01

# %%
type(fire_data['acq_date'][0])
# Out:
# str

# %%
combined = pd.merge(data, fire_data, on="acq_date", how="inner")

# %%
combined
# Out:
#         Year_x  Month_x  Day_x  UTC Hour    acq_date  PM2.5  latitude  \
# 0         2017        5      1         0  2017-05-01   57.1   29.7427
# 1         2017        5      1         0  2017-05-01   57.1   30.4988
# 2         2017        5      1         0  2017-05-01   57.1   30.2280
# 3         2017        5      1         0  2017-05-01   57.1   30.5747
# 4         2017        5      1         0  2017-05-01   57.1   30.4250
# 5         2017        5      1         0  2017-05-01   57.1   29.7439
# 6         2017        5      1         0  2017-05-01   57.1   30.1786
# 7         2017        5      1         0  2017-05-01   57.1   30.4283
# 8         2017        5      1         0  2017-05-01   57.1   30.2613
# 9         2017        5      1         0  2017-05-01   57.1   30.4467
# 10        2017        5      1         0  2017-05-01   57.1   30.4504
# 11        2017        5      1         0  2017-05-01   57.1   30.4938
# 12        2017        5      1         0  2017-05-01   57.1   30.0704
# 13        2017        5      1         0  2017-05-01   57.1   29.8406
# 14        2017        5      1         0  2017-05-01   57.1   30.9331
# 15        2017        5      1         0  2017-05-01   57.1   30.1834
# 16        2017        5      1         0  2017-05-01   57.1   29.8486
# 17        2017        5      1         0  2017-05-01   57.1   30.6562
# 18        2017        5      1         0  2017-05-01   57.1   30.2691
# 19        2017        5      1         0  2017-05-01   57.1   29.1983
# 20        2017        5      1         0  2017-05-01   57.1   29.3212
# 21        2017        5      1         0  2017-05-01   57.1   29.0448
# 22        2017        5      1         0  2017-05-01   57.1   29.4503
# 23        2017        5      1         0  2017-05-01   57.1   29.0439
# 24        2017        5      1         0  2017-05-01   57.1   29.5778
# 25        2017        5      1         0  2017-05-01   57.1   29.4482
# 26        2017        5      1         0  2017-05-01   57.1   29.3213
# 27        2017        5      1         0  2017-05-01   57.1   29.1540
# 28        2017        5      1         0  2017-05-01   57.1   29.2891
# 29        2017        5      1         0  2017-05-01   57.1   29.8210
# ...        ...      ...    ...       ...         ...    ...       ...
# 746752    2019        3     29        15  2019-03-29   56.4   31.4744
# 746753    2019        3     29        16  2019-03-29   72.0   31.4744
# 746754    2019        3     29        17  2019-03-29   73.9   31.4744
# 746755    2019        3     29        18  2019-03-29   78.6   31.4744
# 746756    2019        3     29        19  2019-03-29   74.3   31.4744
# 746757    2019        3     29        20  2019-03-29  106.5   31.4744
# 746758    2019        3     29        21  2019-03-29  124.7   31.4744
# 746759    2019        3     29        22  2019-03-29  138.2   31.4744
# 746760    2019        3     29        23  2019-03-29  143.4   31.4744
# 746761    2019        3     31         0  2019-03-31   82.6   30.2464
# 746762    2019        3     31         1  2019-03-31   82.6   30.2464
# 746763    2019        3     31         2  2019-03-31   77.3   30.2464
# 746764    2019        3     31         3  2019-03-31   78.4   30.2464
# 746765    2019        3     31         4  2019-03-31   63.2   30.2464
# 746766    2019        3     31         5  2019-03-31   68.4   30.2464
# 746767    2019        3     31         6  2019-03-31   67.9   30.2464
# 746768    2019        3     31         7  2019-03-31   53.2   30.2464
# 746769    2019        3     31        11  2019-03-31   34.6   30.2464
# 746770    2019        3     31        12  2019-03-31   25.9   30.2464
# 746771    2019        3     31        13  2019-03-31   26.0   30.2464
# 746772    2019        3     31        14  2019-03-31   36.1   30.2464
# 746773    2019        3     31        15  2019-03-31   25.0   30.2464
# 746774    2019        3     31        16  2019-03-31   41.2   30.2464
# 746775    2019        3     31        17  2019-03-31   46.7   30.2464
# 746776    2019        3     31        18  2019-03-31   50.1   30.2464
# 746777    2019        3     31        19  2019-03-31   50.3   30.2464
# 746778    2019        3     31        20  2019-03-31   50.2   30.2464
# 746779    2019        3     31        21  2019-03-31   50.2   30.2464
# 746780    2019        3     31        22  2019-03-31   39.9   30.2464
# 746781    2019        3     31        23  2019-03-31   38.8   30.2464
#
#         longitude  brightness  scan  acq_time  confidence  version  \
# 0         76.6679       328.7   2.9       618          68      6.2
# 1         74.0669       333.4   1.9       618          77      6.2
# 2         75.1271       330.2   2.3       618          73      6.2
# 3         75.5177       328.7   2.3       618          73      6.2
# 4         75.3941       334.0   2.3       618          80      6.2
# 5         76.6738       328.0   2.9       618          67      6.2
# 6         75.2344       329.7   2.3       618          72      6.2
# 7         75.3897       330.0   2.3       618          74      6.2
# 8         75.6145       329.7   2.4       618          71      6.2
# 9         74.0473       330.2   1.9       618          71      6.2
# 10        74.0283       328.6   1.9       618          67      6.2
# 11        74.0598       337.8   1.9       618          82      6.2
# 12        75.3708       330.2   2.4       618          67      6.2
# 13        75.8776       333.0   2.6       618          77      6.2
# 14        74.8106       331.0   2.1       618          77      6.2
# 15        75.2113       330.2   2.3       618          73      6.2
# 16        75.8732       332.9   2.6       618          76      6.2
# 17        74.0550       324.7   1.9       618          37      6.2
# 18        75.6233       330.7   2.4       618          28      6.2
# 19        76.1655       326.5   2.8       619          46      6.2
# 20        76.6795       327.1   3.0       619          59      6.2
# 21        76.4555       334.1   3.0       619          75      6.2
# 22        76.3808       328.2   2.9       619          65      6.2
# 23        76.4500       337.3   3.0       619          80      6.2
# 24        74.5252       330.2   2.1       619          64      6.2
# 25        76.3749       328.3   2.9       619          64      6.2
# 26        76.6728       326.7   3.0       619          44      6.2
# 27        76.3024       333.6   2.9       619          74      6.2
# 28        75.6024       333.4   1.6       753          64      6.2
# 29        76.0341       335.0   1.5       753          75      6.2
# ...           ...         ...   ...       ...         ...      ...
# 746752    75.6168       314.5   1.8       612          71      6.3
# 746753    75.6168       314.5   1.8       612          71      6.3
# 746754    75.6168       314.5   1.8       612          71      6.3
# 746755    75.6168       314.5   1.8       612          71      6.3
# 746756    75.6168       314.5   1.8       612          71      6.3
# 746757    75.6168       314.5   1.8       612          71      6.3
# 746758    75.6168       314.5   1.8       612          71      6.3
# 746759    75.6168       314.5   1.8       612          71      6.3
# 746760    75.6168       314.5   1.8       612          71      6.3
# 746761    74.2578       312.5   1.1       600          53      6.3
# 746762    74.2578       312.5   1.1       600          53      6.3
# 746763    74.2578       312.5   1.1       600          53      6.3
# 746764    74.2578       312.5   1.1       600          53      6.3
# 746765    74.2578       312.5   1.1       600          53      6.3
# 746766    74.2578       312.5   1.1       600          53      6.3
# 746767    74.2578       312.5   1.1       600          53      6.3
# 746768    74.2578       312.5   1.1       600          53      6.3
# 746769    74.2578       312.5   1.1       600          53      6.3
# 746770    74.2578       312.5   1.1       600          53      6.3
# 746771    74.2578       312.5   1.1       600          53      6.3
# 746772    74.2578       312.5   1.1       600          53      6.3
# 746773    74.2578       312.5   1.1       600          53      6.3
# 746774    74.2578       312.5   1.1       600          53      6.3
# 746775    74.2578       312.5   1.1       600          53      6.3
# 746776    74.2578       312.5   1.1       600          53      6.3
# 746777    74.2578       312.5   1.1       600          53      6.3
# 746778    74.2578       312.5   1.1       600          53      6.3
# 746779    74.2578       312.5   1.1       600          53      6.3
# 746780    74.2578       312.5   1.1       600          53      6.3
# 746781    74.2578       312.5   1.1       600          53      6.3
#
#         bright_t31    frp  type  Day_y  Month_y  Year_y
# 0            311.5   48.2     0    1.0      5.0  2017.0
# 1            312.7   33.6     0    1.0      5.0  2017.0
# 2            315.3   28.3     0    1.0      5.0  2017.0
# 3            312.8   27.4     0    1.0      5.0  2017.0
# 4            313.5   47.6     0    1.0      5.0  2017.0
# 5            311.6   41.5     0    1.0      5.0  2017.0
# 6            315.1   25.6     0    1.0      5.0  2017.0
# 7            313.4   29.3     0    1.0      5.0  2017.0
# 8            313.6   31.5     0    1.0      5.0  2017.0
# 9            313.5   23.1     0    1.0      5.0  2017.0
# 10           312.7   19.1     0    1.0      5.0  2017.0
# 11           312.4   51.3     0    1.0      5.0  2017.0
# 12           313.7   30.8     0    1.0      5.0  2017.0
# 13           312.6   58.3     0    1.0      5.0  2017.0
# 14           315.1   30.9     0    1.0      5.0  2017.0
# 15           314.6   28.0     0    1.0      5.0  2017.0
# 16           313.2   57.6     0    1.0      5.0  2017.0
# 17           308.9   15.2     0    1.0      5.0  2017.0
# 18           314.1   34.0     0    1.0      5.0  2017.0
# 19           310.7   32.3     0    1.0      5.0  2017.0
# 20           311.0   37.7     0    1.0      5.0  2017.0
# 21           312.9   77.6     0    1.0      5.0  2017.0
# 22           311.4   36.6     0    1.0      5.0  2017.0
# 23           313.2  101.4     0    1.0      5.0  2017.0
# 24           312.9   25.1     0    1.0      5.0  2017.0
# 25           311.4   38.3     0    1.0      5.0  2017.0
# 26           310.9   35.4     0    1.0      5.0  2017.0
# 27           310.7   74.0     0    1.0      5.0  2017.0
# 28           319.7   15.3     0    1.0      5.0  2017.0
# 29           313.5   26.5     0    1.0      5.0  2017.0
# ...            ...    ...   ...    ...      ...     ...
# 746752       299.6   13.5     0   29.0      3.0  2019.0
# 746753       299.6   13.5     0   29.0      3.0  2019.0
# 746754       299.6   13.5     0   29.0      3.0  2019.0
# 746755       299.6   13.5     0   29.0      3.0  2019.0
# 746756       299.6   13.5     0   29.0      3.0  2019.0
# 746757       299.6   13.5     0   29.0      3.0  2019.0
# 746758       299.6   13.5     0   29.0      3.0  2019.0
# 746759       299.6   13.5     0   29.0      3.0  2019.0
# 746760       299.6   13.5     0   29.0      3.0  2019.0
# 746761       300.9    6.9     0   31.0      3.0  2019.0
# 746762       300.9    6.9     0   31.0      3.0  2019.0
# 746763       300.9    6.9     0   31.0      3.0  2019.0
# 746764       300.9    6.9     0   31.0      3.0  2019.0
# 746765       300.9    6.9     0   31.0      3.0  2019.0
# 746766       300.9    6.9     0   31.0      3.0  2019.0
# 746767       300.9    6.9     0   31.0      3.0  2019.0
# 746768       300.9    6.9     0   31.0      3.0  2019.0
# 746769       300.9    6.9     0   31.0      3.0  2019.0
# 746770       300.9    6.9     0   31.0      3.0  2019.0
# 746771       300.9    6.9     0   31.0      3.0  2019.0
# 746772       300.9    6.9     0   31.0      3.0  2019.0
# 746773       300.9    6.9     0   31.0      3.0  2019.0
# 746774       300.9    6.9     0   31.0      3.0  2019.0
# 746775       300.9    6.9     0   31.0      3.0  2019.0
# 746776       300.9    6.9     0   31.0      3.0  2019.0
# 746777       300.9    6.9     0   31.0      3.0  2019.0
# 746778       300.9    6.9     0   31.0      3.0  2019.0
# 746779       300.9    6.9     0   31.0      3.0  2019.0
# 746780       300.9    6.9     0   31.0      3.0  2019.0
# 746781       300.9    6.9     0   31.0      3.0  2019.0
#
# [746782 rows x 19 columns]

# %%
Aggregation={'PM2.5':'mean'}
combined_data=pd.DataFrame()
combined_data=combined.groupby(['Year_x','Month_x','Day_x']).agg(Aggregation).reset_index()
# a["acq_date"] = data["acq_date"]
combined_data.head()
#type(a['acq_date'][0])
# Out:
#    Year_x  Month_x  Day_x       PM2.5
# 0    2017        5      1   92.170833
# 1    2017        5      2  133.978261
# 2    2017        5      3  119.283333
# 3    2017        5      4  136.308696
# 4    2017        5      5  159.175000

# %%
columns = list(['latitude', 'longitude', 'brightness', 'scan', 'confidence', 'bright_t31', 'frp'])

combined_data[columns] = combined[columns]

# %%
combined_data.head()
# Out:
#    Year_x  Month_x  Day_x       PM2.5  latitude  longitude  brightness  scan  \
# 0    2017        5      1   92.170833   29.7427    76.6679       328.7   2.9
# 1    2017        5      2  133.978261   30.4988    74.0669       333.4   1.9
# 2    2017        5      3  119.283333   30.2280    75.1271       330.2   2.3
# 3    2017        5      4  136.308696   30.5747    75.5177       328.7   2.3
# 4    2017        5      5  159.175000   30.4250    75.3941       334.0   2.3
#
#    confidence  bright_t31   frp
# 0          68       311.5  48.2
# 1          77       312.7  33.6
# 2          73       315.3  28.3
# 3          73       312.8  27.4
# 4          80       313.5  47.6

# %%
features = list(['Year_x', 'Month_x', 'Day_x', 'latitude', 'longitude', 'brightness', 'scan', 'confidence', 'bright_t31', 'frp'])

# %%
feature_set = combined_data[features]

# %%
target = combined_data['PM2.5']

# %%
target.describe()
# Out:
# count    428.000000
# mean     129.099050
# std       79.294055
# min       18.907143
# 25%       71.989583
# 50%      107.543750
# 75%      170.918750
# max      546.900000
# Name: PM2.5, dtype: float64

# %%
feature_set.head()

# %%
from sklearn.preprocessing import StandardScaler
# X = StandardScaler().fit_transform(feature_set)

scaler=StandardScaler()#instantiate
scaler.fit(combined_data) # compute the mean and standard which will be used in the next command
X_scaled=scaler.transform(combined_data)# fit and transform can be applied together and I leave that for simple exercise
# we can check the minimum and maximum of the scaled features which we expect to be 0 and 1
print("after scaling minimum", X_scaled.min(axis=0)) 

from sklearn.decomposition import PCA

pca = PCA(n_components=3) 
pca.fit(X_scaled) 
X_pca=pca.transform(X_scaled) 
#let's check the shape of X_pca array
print("shape of X_pca", X_pca.shape)

X_pca = pd.DataFrame(X_pca)
X_pca.head()

ex_variance=np.var(X_pca,axis=0)
ex_variance_ratio = ex_variance/np.sum(ex_variance)
print(ex_variance_ratio)

target_categorical = []
for value in target:
    if value > 18 and value < 72:
        target_categorical.append(0)
    elif value > 72 and value < 120:
        target_categorical.append(1)
    else:
        target_categorical.append(2)

target_categorical = pd.DataFrame(target_categorical)

# %%
target_categorical.head()
# Out:
#    0
# 0  1
# 1  2
# 2  1
# 3  2
# 4  2

# %%
plt.matshow(pca.components_,cmap='viridis')
plt.yticks([0,1,2],['1st Comp','2nd Comp','3rd Comp'],fontsize=10)
plt.colorbar()
plt.xticks(11,features,rotation=65, ha="left")
plt.tight_layout()
plt.show()
# Out:
# c:\users\meeta\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   """

# %%
from apyori import apriori

# %%
records = []
for i in range(0, len(combined_data)):
    records.append([str(combined_data.values[i,j]) for j in range(0, 11)])

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print(len(association_rules))
